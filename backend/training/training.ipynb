# %%
# %pip install ultralytics
# %pip install roboflow

# %%
import wandb
wandb.login()

# %%
# Download the dataset
from roboflow import Roboflow
rf = Roboflow(api_key="5axk331R3RDBhH3uGZtR")
project = rf.workspace("mlproject-q2erh").project("ml-project-zq8l9")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Move the dataset to the correct location
import shutil

for folder in ["train", "valid", "test"]:
    shutil.move(f"ML-project-3/{folder}", f"ML-project-3/ML-project-3/{folder}")

# %%
# Train YOLOv5 on the custom dataset
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=12
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
