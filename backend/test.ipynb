# %%
from detector import Detector 
from config import MODEL_PATH

# %%
detector = Detector(MODEL_PATH)
data = detector.load_data()

# %%
data_ = {k:len(v) for k, v in data.items()}
data_ = {k: v for k, v in sorted(data_.items(), key=lambda item: item[1], reverse=True)}

# %%
data_
# Out:
# [('0', 27),
#  ('5', 24),
#  ('3', 24),
#  ('', 20),
#  ('1', 15),
#  ('2', 15),
#  ('7', 11),
#  ('11', 9),
#  ('55', 7),
#  ('4', 6),
#  ('9', 6),
#  ('18', 6),
#  ('53', 6),
#  ('35', 6),
#  ('32', 6),
#  ('8', 6),
#  ('17', 6),
#  ('1586', 6),
#  ('20', 6),
#  ('327', 5),
#  ('57', 5),
#  ('955', 5),
#  ('1065', 5),
#  ('81', 4),
#  ('82', 4),
#  ('1571', 4),
#  ('51', 4),
#  ('267', 4),
#  ('3041', 4),
#  ('3352', 4),
#  ('3244', 4),
#  ('715', 4),
#  ('139', 4),
#  ('59', 4),
#  ('439', 4),
#  ('1560', 4),
#  ('402', 4),
#  ('3043', 4),
#  ('31', 4),
#  ('14', 4),
#  ('3299', 4),
#  ('13', 3),
#  ('707', 3),
#  ('621', 3),
#  ('21', 3),
#  ('3054', 3),
#  ('3170', 3),
#  ('3269', 3),
#  ('73', 3),
#  ('3082', 3),
#  ('701', 3),
#  ('2123', 3),
#  ('3068', 3),
#  ('149', 3),
#  ('340', 3),
#  ('292', 3),
#  ('27', 3),
#  ('195', 3),
#  ('1993', 3),
#  ('786', 3),
#  ('1997', 3),
#  ('1984', 3),
#  ('33', 3),
#  ('3264', 3),
#  ('65', 3),
#  ('3295', 3),
#  ('328', 3),
# ...
